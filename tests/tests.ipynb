# %%
import pandas as pd
import numpy as np
import streamlit as st
from io import BytesIO

# %%
xp = pd.read_csv('temp3068439863306856865.csv',sep=';')

# %%
xp_file = st.file_uploader("Jogue aqui o arquivo .csv XP Investimentos")

xp = pd.read_csv(xp_file)

# Editando arquivo csv para usar no google sheets.

xp['Valor'] = xp['Valor'].astype('str')

xp['Valor'] = xp['Valor'].str.replace('R\$', '', regex=True)

xp.drop(columns=['Estabelecimento','Parcela'],inplace=True)

st.dataframe(xp)

xp = to_excel(xp)

st.download_button(label="Download",data=xp,file_name='xp.xlsx')

# %%
xp
# Out:
#           Data         Portador     Valor
# 0   01/02/2023  FILIPE AGUIAR R   -145,50
# 1   03/02/2023  FILIPE AGUIAR R     64,80
# 2   03/02/2023  FILIPE AGUIAR R     14,90
# 3   03/02/2023  FILIPE AGUIAR R     46,20
# 4   04/02/2023  FILIPE AGUIAR R    104,41
# 5   04/02/2023  FILIPE AGUIAR R     83,20
# 6   06/02/2023  FILIPE AGUIAR R    118,60
# 7   07/02/2023  FILIPE AGUIAR R     59,90
# 8   10/02/2023  FILIPE AGUIAR R     55,05
# 9   11/02/2023  FILIPE AGUIAR R     25,00
# 10  12/02/2023  FILIPE AGUIAR R     31,41
# 11  12/02/2023  FILIPE AGUIAR R    159,83
# 12  12/02/2023  FILIPE AGUIAR R     97,10
# 13  14/02/2023  FILIPE AGUIAR R     88,83
# 14  14/02/2023  FILIPE AGUIAR R     29,98
# 15  25/01/2023  FILIPE AGUIAR R    145,50
# 16  27/01/2023  FILIPE AGUIAR R    119,90
# 17  27/01/2023  FILIPE AGUIAR R     30,67
# 18  27/01/2023  FILIPE AGUIAR R    110,50
# 19  27/01/2023  FILIPE AGUIAR R   -309,90
# 20  28/01/2023  FILIPE AGUIAR R     16,99
# 21  28/01/2023  FILIPE AGUIAR R     15,00
# 22  28/01/2023  FILIPE AGUIAR R     23,97
# 23  28/01/2023  FILIPE AGUIAR R     41,47
# 24  28/01/2023  FILIPE AGUIAR R     31,91
# 25  30/01/2023  FILIPE AGUIAR R    232,04
# 26  30/01/2023  FILIPE AGUIAR R     64,64
# 27  30/01/2023  FILIPE AGUIAR R     61,99
# 28  31/01/2023  FILIPE AGUIAR R     33,31
